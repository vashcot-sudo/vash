# %% [markdown]
# <a href="https://colab.research.google.com/github/vashcot-sudo/vash/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Практическое задание №2. Условный оператор. Циклы. Функции.

# %% [markdown]
# ЗАДАНИЕ 1

# %%
password1 = input("Введите пароль: ")
password2 = input("Подтвердите пароль: ")
if password1 == password2:
    print("Пароль принят")
else:
    print("Пароль не принят")
# Out:
# Введите пароль: qwerty
# Подтвердите пароль: qwerty
# Пароль принят

# %% [markdown]
# ЗАДАНИЕ 2

# %%
age = int(input("Введите ваш возраст: "))
if age >= 18:
    print("Доступ разрешен")
else:
    print("Доступ запрещен")

# %% [markdown]
# ЗАДАНИЕ 3

# %%
number1 = int(input("Введите первое число: "))
number2 = int(input("Введите второе число: "))
if number1 < number2:
    print(number1)
else:
    print(number2)
# Out:
# Введите первое число: 11
# Введите второе число: 8
# 8

# %% [markdown]
# ЗАДАНИЕ 4

# %%
number1 = int(input("Введите первое число: "))
number2 = int(input("Введите второе число: "))
number3 = int(input("Введите третье число: "))
num = 1
if number2 - number1 == number3 - number2:
    print("ДА")
else:
    print("НЕТ")
# Out:
# Введите первое число: 1
# Введите второе число: 2
# Введите третье число: 3
# ДА

# %% [markdown]
# ЗАДАНИЕ 5

# %%
number1 = int(input("Введите первое число: "))
number2 = int(input("Введите второе число: "))
number3 = int(input("Введите третье число: "))
# Инициализируем счётчик
i = 0
# Проверяем каждое число и добавляем положительные к счётчику
if number1 > 0:
   i = i + number1
if number2 > 0:
    i = i + number2
if number3 > 0:
    i = i + number3
# Выводим результат
print(i)
# Out:
# Введите первое число: 3
# Введите второе число: 5
# Введите третье число: 7
# 15

# %% [markdown]
# ЗАДАНИЕ 6

# %%
number1 = int(input("Введите первое число: "))
number2 = int(input("Введите второе число: "))
number3 = int(input("Введите третье число: "))
number4 = int(input("Введите четвёртое число: "))
if number1 <= number2 and number1 <= number3 and number1 <= number4:
  print(number1)
elif number2 <= number1 and number2 <= number3 and number2 <= number4:
  print(number2)
elif number3 <= number1 and number3 <= number2 and number3 <= number4:
  print(number3)
else:
  print(number4)
# Out:
# Введите первое число: 5
# Введите второе число: 4
# Введите третье число: 8
# Введите четвёртое число: 1
# 1

# %% [markdown]
# ЗАДАНИЕ 7

# %%
year = int(input("Введите год: "))
if year % 4 == 0 and year % 100 != 0 or year % 400 == 0:
    print("ДА")
else:
    print("НЕТ")
# Out:
# Введите год: 2020
# ДА

# %% [markdown]
# ЗАДАНИЕ 8

# %%
number1 = int(input("Введите первое число: "))
number2 = int(input("Введите второе число: "))
number3 = int(input("Введите третье число: "))
if number2 < number1 < number3 or number3 < number1 < number2:
    print(number1)
elif number1 < number2 < number3 or number3 < number2 < number1:
    print(number2)
else:
    print(number3)
# Out:
# Введите первое число: 1
# Введите второе число: 2
# Введите третье число: 3
# 2

# %% [markdown]
# ЗАДАНИЕ 9
