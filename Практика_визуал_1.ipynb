# %% [markdown]
# <a href="https://colab.research.google.com/github/vashcot-sudo/vash/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%B2%D0%B8%D0%B7%D1%83%D0%B0%D0%BB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Пример

# %% [markdown]
# # Задание

# %% [markdown]
# * Создайте датасет, который содержит 7 переменных: 3 категориальных, 3 числовых, 1 дата/время. Тему выберите сами.
#
# * Постройте гипотезу.
#
# * Проверьте гипотезу с помощью визуализации.
#
# * Сделайте выводы.

# %%
import pandas as pd
import numpy as np

np.random.seed(0)
# Создание категорийных признаков
# Создание категорийной переменной с тремя категориями Смартфон, Ноутбук, Наушники
gadgets = np.random.choice(['Смартфон', 'Ноутбук', 'Наушники'], size=40, replace=True)
# Создание категорийной переменной с двумя категориями, повторяющимися по очереди: голубой, зеленый
colour = ['голубой',"зеленый"]*20
brand = ["Apple", 'Samsung', 'Lenovo', 'Honor', 'Asus'] * 8

# Создание числовых признаков
number = np.random.randint(7,25,size=40) # рандомно 40 целых чисел от 7 до 25
quantity_stock = np.random.randint(0, 100, size=40) # количество на складе (рандомно 40 целых цисел от 0 до 100)
#price = np.random.normal(85000,93000,size=40)
price = np.round(np.random.uniform(85000,93000,40), 2)
#price=[85000,86000,87000,91000,93000,88000,89000,90000,91000,92000,93000,85000,86000,87000,90000,92000,88000,89000,90000,91000,92000,93000,91000,87000,120000,90000,88000,93000,87000,85000,92000,90000,91000,85000,87000,92000,87000,120000,87000,91000,]
numerical = np.random.randn(40) # 40 рандомных чисел

# Создание признака дата/время
priv = pd.to_datetime(pd.date_range(start='2025-07-19', periods=40, freq='D'))

# Создание датасета
data = {
    'gadgets': gadgets,
    'colour': colour,
    'brand': brand,
    'number': number,
    'quantity_stock': quantity_stock,
    'price': price,
    'numerical': numerical,
    'priv':priv
}

df = pd.DataFrame(data)

# вывод датасета на экран
display(df)
# Out:
#      gadgets   colour    brand  number  quantity_stock     price  numerical  \
# 0   Смартфон  голубой    Apple      18              85  89185.98  -1.270485
# 1    Ноутбук  зеленый  Samsung       9              48  85751.52   0.969397
# 2   Смартфон  голубой   Lenovo       7              49  89607.57  -1.173123
# 3    Ноутбук  зеленый    Honor       7              69  92434.37   1.943621
# 4    Ноутбук  голубой     Asus      11              41  87548.55  -0.413619
# 5   Наушники  зеленый    Apple      12              35  90339.28  -0.747455
# 6   Смартфон  голубой  Samsung      13              64  86054.38   1.922942
# 7   Наушники  зеленый   Lenovo      15              95  90730.62   1.480515
# 8   Смартфон  голубой    Honor      24              69  87315.25   1.867559
# 9   Смартфон  зеленый     Asus      22              94  86465.53   0.906045
# 10  Смартфон  голубой    Apple      11               0  89692.10  -0.861226
# ...

# %% [markdown]
# Гипотеза: количество продаж не зависит от бренда и цвета гаджета.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.boxplot(x='brand', y='number', data=df, palette='Set2', hue=colour)
plt.title('Зависимость количества продаж от бренда и цвета гаджета')
plt.xlabel('Бренд')
plt.ylabel('Количество продаж')
plt.tight_layout()
plt.show()

# %% [markdown]
# Гипотеза подтверждается. График показывает, что количество продаж не зависит ни от бренда, ни от цвета гаджета
